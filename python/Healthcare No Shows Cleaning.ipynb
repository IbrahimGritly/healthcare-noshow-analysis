# %% [markdown]
# # Healthcare No-Show Analytics Data Cleaning

# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/aaliyahgritly/Downloads/Bebo study items/(P5) Healthcare No Shows Project/Medical-Noshows-May-2016.csv')

# %%
df.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# 1         0           0        0             0      No
# 2         0           0        0             0      No
# 3         0           0        0             0      No
# 4         1           0        0             0      No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %%
df.groupby('Age')['No-show'].value_counts(ascending=False)
# Out:
# Age   No-show
# -1    No            1
#  0    No         2900
#       Yes         639
#  1    No         1858
#       Yes         415
#                  ...
#  99   No            1
#  100  No            4
#  102  No            2
#  115  Yes           3
#       No            2
# Name: count, Length: 204, dtype: int64

# %%
df.groupby('Neighbourhood')['No-show'].value_counts()
# Out:
# Neighbourhood    No-show
# AEROPORTO        No            7
#                  Yes           1
# ANDORINHAS       No         1741
#                  Yes         521
# ANTÔNIO HONÓRIO  No          221
#                             ...
# TABUAZEIRO       Yes         573
# UNIVERSITÁRIO    No          120
#                  Yes          32
# VILA RUBIM       No          710
#                  Yes         141
# Name: count, Length: 160, dtype: int64

# %% [markdown]
# Start cleaning process by standardizing column names

# %%
# Making column names consistent
df.columns = df.columns.str.strip().str.lower().str.replace("-", "_").str.replace(" ", "_")

# %% [markdown]
# Convert data types

# %%
# Changing date columns to datetime format
df['appointmentday'] = pd.to_datetime(df['appointmentday'])
df['scheduledday'] = pd.to_datetime(df['scheduledday'])

# %%
df['patientid'] = df['patientid'].astype('string') # Converting patient ID to string type

# %% [markdown]
# Create `waiting_days` column

# %%
# Firts, this will extract the date part from the datetime columns
df['scheduled_date'] = df['scheduledday'].dt.date 
df['appointment_date'] = df['appointmentday'].dt.date 

# Now, we can calculate the difference in days
df['waiting_days'] = (pd.to_datetime(df['appointment_date']) - pd.to_datetime(df['scheduled_date'])).dt.days

# %%
df['waiting_days'].describe() # The min value is negative, which is not possible, so we need to address that.
# Out:
# count    110527.000000
# mean         10.183702
# std          15.254996
# min          -6.000000
# 25%           0.000000
# 50%           4.000000
# 75%          15.000000
# max         179.000000
# Name: waiting_days, dtype: float64

# %% [markdown]
# A small number of records showed appointment dates earlier than scheduled dates.
# These were treated as same-day appointments by setting waiting time to zero, aligning with real-world scheduling logic.

# %%
# These are the rows with negative waiting days
df[df['waiting_days'] < 0][['scheduledday', 'appointmentday', 'scheduled_date', 'appointment_date', 'waiting_days']].head(10)
# Out:
#                    scheduledday            appointmentday scheduled_date  \
# 27033 2016-05-10 10:51:53+00:00 2016-05-09 00:00:00+00:00     2016-05-10
# 55226 2016-05-18 14:50:41+00:00 2016-05-17 00:00:00+00:00     2016-05-18
# 64175 2016-05-05 13:43:58+00:00 2016-05-04 00:00:00+00:00     2016-05-05
# 71533 2016-05-11 13:49:20+00:00 2016-05-05 00:00:00+00:00     2016-05-11
# 72362 2016-05-04 06:50:57+00:00 2016-05-03 00:00:00+00:00     2016-05-04
#
#       appointment_date  waiting_days
# 27033       2016-05-09            -1
# 55226       2016-05-17            -1
# 64175       2016-05-04            -1
# 71533       2016-05-05            -6
# 72362       2016-05-03            -1

# %%
df['waiting_days'] = pd.to_datetime(df['waiting_days'], errors='coerce')
df['appointment_date'] = pd.to_datetime(df['appointment_date'], errors='coerce')
df['scheduled_date'] = pd.to_datetime(df['scheduled_date'], errors='coerce')

# %%
df['waiting_days'] = (df['appointment_date'] - df['scheduled_date']).dt.days

# %%
df['scheduled_date'] = pd.to_datetime(df['scheduledday']).dt.normalize()
df['appointment_date'] = pd.to_datetime(df['appointmentday']).dt.normalize() # Normalizing to remove time component

df['waiting_days'] = (df['appointment_date'] - df['scheduled_date']).dt.days

# %%
# Setting negative waiting days to zero
df.loc[df['waiting_days'] < 0, 'waiting_days'] = 0

# %%
df['waiting_days'].describe() # Now the min value shows 0
# Out:
# count    110527.000000
# mean         10.183792
# std          15.254924
# min           0.000000
# 25%           0.000000
# 50%           4.000000
# 75%          15.000000
# max         179.000000
# Name: waiting_days, dtype: float64

# %% [markdown]
# Create `appointment_weekday` and `appointment_month` columns

# %%
df['appointment_weekday'] = df['appointmentday'].dt.day_name() # Extracting day name from appointment date

df['appointment_month'] = df['appointmentday'].dt.month_name() # Extracting month name from appointment date

# %% [markdown]
# Create a `has_disability` column

# %%
df['has_disability'] = df['handcap'].apply(lambda x: 1 if x > 0 else 0) # 1 if patient has any disability, else 0

# %% [markdown]
# Replace negatives in `age` column

# %%
df.loc[df['age'] < 0, 'age'] = pd.NA # Replacing negative ages with NaN

# %%
df['age'].describe()
# Out:
# count    110526.000000
# mean         37.089219
# std          23.110026
# min           0.000000
# 25%          18.000000
# 50%          37.000000
# 75%          55.000000
# max         115.000000
# Name: age, dtype: float64

# %% [markdown]
# Create column `no_show_flag` to make no-show less confusing

# %%
# Here, Yes = 1 (no-show), No = 0 (showed up)
df['no_show_flag'] = df['no_show'].map({'Yes': 1, 'No': 0})

# %%
df[['no_show', 'no_show_flag']].value_counts()
# Out:
# no_show  no_show_flag
# No       0               88208
# Yes      1               22319
# Name: count, dtype: int64

# %% [markdown]
# Create age groups
# Child: 0-12
# Teen: 13-17
# Young Adult: 18-35
# Adult: 36-55
# Senior: 56-75
# Elderly: 76+

# %%
def categorize_age(age):
    if age < 0 or pd.isna(age):
        return 'Unknown'
    elif age <= 12:
        return 'Child (0-12)'
    elif age <= 17:
        return 'Teen (13-17)'
    elif age <= 35:
        return 'Young Adult (18-35)'  
    elif age <= 55:
        return 'Adult (36-55)' 
    elif age <= 75:
        return 'Senior (56-75)'
    else:
        return 'Elderly (76+)'

# %%
df['age_group'] = df['age'].apply(categorize_age) # Applying the function to create age groups

# %%
df['age_group'].value_counts()
# Out:
# age_group
# Adult (36-55)          30019
# Young Adult (18-35)    25624
# Senior (56-75)         22112
# Child (0-12)           21036
# Teen (13-17)            6343
# Elderly (76+)           5392
# Unknown                    1
# Name: count, dtype: int64

# %% [markdown]
# Create wait time buckets

# %%
def categorize_waiting_time(days):
    if pd.isna(days):
        return 'Unknown'
    elif days == 0:
        return 'Same Day'
    elif days <= 7:
        return '1-7 Days'
    elif days <= 14:
        return '8-14 Days'
    elif days <= 30:
        return '15-30 Days'
    else:
        return '30+ Days'

# %%
df['wait_time_group'] = df['waiting_days'].apply(categorize_waiting_time) # Applying the function to waiting_days column to create waiting time groups

# %%
df[['wait_time_group']].value_counts()
# Out:
# wait_time_group
# Same Day           38568
# 1-7 Days           32185
# 15-30 Days         17371
# 8-14 Days          12025
# 30+ Days           10378
# Name: count, dtype: int64

# %% [markdown]
# Create a high risk no-show flag

# %%
df['high_risk_no_show'] = (df['waiting_days'] > 14) & (df['sms_received'] == 0).astype(int) # if they did not receive SMS and waiting days > 14, then high risk no show

# %%
df['high_risk_no_show'].value_counts()
# Out:
# high_risk_no_show
# False    99708
# True     10819
# Name: count, dtype: int64

# %% [markdown]
# Now to do some sanity checks

# %%
overall_no_show = df['no_show_flag'].mean()
print(f"Overall no-show rate: {overall_no_show:.2%}")
# Out:
# Overall no-show rate: 20.19%

# %%
sms_no_show = df.groupby('sms_received')['no_show_flag'].mean() 
print(sms_no_show)

# Maybe hospitals send SMS more often to patients who are already at higher risk of missing (older patients, long wait times, first-time patients)

# 16.7% no-show rate for those who did not receive SMS
# 27.6% no-show rate for those who received SMS
# Out:
# sms_received
# 0    0.167033
# 1    0.275745
# Name: no_show_flag, dtype: float64

# %%
age_no_show = df.groupby('age_group')['no_show_flag'].mean().sort_index()
print(age_no_show)

# Adults: 19.7% no-show rate
# Young Adults: 23.8% no-show rate
# Seniors: 15.5% no-show rate
# Children: 20.5% no-show rate
# Elderly: 16.1% no-show rate
# Teens: 26.6% no-show rate
# Out:
# age_group
# Adult (36-55)          0.197075
# Child (0-12)           0.204744
# Elderly (76+)          0.161350
# Senior (56-75)         0.155255
# Teen (13-17)           0.266435
# Unknown                0.000000
# Young Adult (18-35)    0.238175
# Name: no_show_flag, dtype: float64

# %%
wait_no_show = df.groupby('wait_time_group')['no_show_flag'].mean().sort_index()
print(wait_no_show)

# Same Day: 4.7% no-show rate
# 1-7 Days: 24.1% no-show rate
# 8-14 Days: 30.5% no-show rate
# 15-30 Days: 32.6% no-show rate
# 30+ Days: 33% no-show rate

# Longer wait times are associated with higher no-show rates
# Out:
# wait_time_group
# 1-7 Days      0.241479
# 15-30 Days    0.325888
# 30+ Days      0.330025
# 8-14 Days     0.304699
# Same Day      0.046593
# Name: no_show_flag, dtype: float64

# %%
risk_no_show = df.groupby('high_risk_no_show')['no_show_flag'].mean()
print(risk_no_show)
# Out:
# high_risk_no_show
# False    0.183576
# True     0.371106
# Name: no_show_flag, dtype: float64

# %%
gender_no_show = df.groupby('gender')['no_show_flag'].mean()
print(gender_no_show)
# Out:
# gender
# F    0.203146
# M    0.199679
# Name: no_show_flag, dtype: float64

# %% [markdown]
# Rename some columns for clarity

# %%
df.rename(columns = {'patientid': 'patient_id', 'appointmentid': 'appointment_id', 
                     'scheduledday': 'scheduled_day', 'appointmentday': 'appointment_day'}, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 24 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   patient_id           110527 non-null  string
#  1   appointment_id       110527 non-null  int64
#  2   gender               110527 non-null  object
#  3   scheduled_day        110527 non-null  datetime64[ns, UTC]
#  4   appointment_day      110527 non-null  datetime64[ns, UTC]
#  5   age                  110526 non-null  float64
#  6   neighbourhood        110527 non-null  object
#  7   scholarship          110527 non-null  int64
#  8   hipertension         110527 non-null  int64
#  9   diabetes             110527 non-null  int64
#  10  alcoholism           110527 non-null  int64
#  11  handcap              110527 non-null  int64
#  12  sms_received         110527 non-null  int64
#  13  no_show              110527 non-null  object
#  14  scheduled_date       110527 non-null  datetime64[ns, UTC]
#  15  appointment_date     110527 non-null  datetime64[ns, UTC]
#  16  waiting_days         110527 non-null  int64
#  17  appointment_weekday  110527 non-null  object
#  18  appointment_month    110527 non-null  object
#  19  has_disability       110527 non-null  int64
#  20  no_show_flag         110527 non-null  int64
#  21  age_group            110527 non-null  object
#  22  wait_time_group      110527 non-null  object
#  23  high_risk_no_show    110527 non-null  bool
# dtypes: bool(1), datetime64[ns, UTC](4), float64(1), int64(10), object(7), string(1)
# memory usage: 19.5+ MB

# %%
df.head()
# Out:
#           patient_id  appointment_id gender             scheduled_day  \
# 0   29872499824296.0         5642903      F 2016-04-29 18:38:08+00:00
# 1  558997776694438.0         5642503      M 2016-04-29 16:08:27+00:00
# 2    4262962299951.0         5642549      F 2016-04-29 16:19:04+00:00
# 3     867951213174.0         5642828      F 2016-04-29 17:29:31+00:00
# 4    8841186448183.0         5642494      F 2016-04-29 16:07:23+00:00
#
#             appointment_day   age      neighbourhood  scholarship  \
# 0 2016-04-29 00:00:00+00:00  62.0    JARDIM DA PENHA            0
# 1 2016-04-29 00:00:00+00:00  56.0    JARDIM DA PENHA            0
# 2 2016-04-29 00:00:00+00:00  62.0      MATA DA PRAIA            0
# 3 2016-04-29 00:00:00+00:00   8.0  PONTAL DE CAMBURI            0
# 4 2016-04-29 00:00:00+00:00  56.0    JARDIM DA PENHA            0
#
#    hipertension  diabetes  ...            scheduled_date  \
# 0             1         0  ... 2016-04-29 00:00:00+00:00
# 1             0         0  ... 2016-04-29 00:00:00+00:00
# 2             0         0  ... 2016-04-29 00:00:00+00:00
# 3             0         0  ... 2016-04-29 00:00:00+00:00
# 4             1         1  ... 2016-04-29 00:00:00+00:00
#
#            appointment_date  waiting_days appointment_weekday  \
# 0 2016-04-29 00:00:00+00:00             0              Friday
# 1 2016-04-29 00:00:00+00:00             0              Friday
# 2 2016-04-29 00:00:00+00:00             0              Friday
# 3 2016-04-29 00:00:00+00:00             0              Friday
# 4 2016-04-29 00:00:00+00:00             0              Friday
#
#   appointment_month has_disability  no_show_flag       age_group  \
# 0             April              0             0  Senior (56-75)
# 1             April              0             0  Senior (56-75)
# 2             April              0             0  Senior (56-75)
# 3             April              0             0    Child (0-12)
# 4             April              0             0  Senior (56-75)
#
#   wait_time_group  high_risk_no_show
# 0        Same Day              False
# 1        Same Day              False
# 2        Same Day              False
# 3        Same Day              False
# 4        Same Day              False
#
# [5 rows x 24 columns]

# %% [markdown]
# Import the cleaned version of the data into a csv

# %%
df.to_csv('/Users/aaliyahgritly/Downloads/Bebo study items/(P5) Healthcare No Shows Project/Medical-Noshows-May-2016-Cleaned.csv', index=False)

# %%
pd.set_option('display.max_columns', None)
df.sort_values('appointment_id').head()
# Out:
#                patient_id  appointment_id gender             scheduled_day  \
# 3764    832256398961987.0         5030230      F 2015-11-10 07:13:56+00:00
# 46292    91637474953513.0         5122866      M 2015-12-03 08:17:28+00:00
# 102795    1216586867796.0         5134197      F 2015-12-07 10:40:59+00:00
# 102797   31899595421534.0         5134220      F 2015-12-07 10:42:42+00:00
# 102796    9582232334148.0         5134223      F 2015-12-07 10:43:01+00:00
#
#                  appointment_day   age  neighbourhood  scholarship  \
# 3764   2016-05-04 00:00:00+00:00  51.0    RESISTÊNCIA            0
# 46292  2016-05-02 00:00:00+00:00  34.0     VILA RUBIM            0
# 102795 2016-06-03 00:00:00+00:00  27.0  SÃO CRISTÓVÃO            1
# 102797 2016-06-03 00:00:00+00:00  48.0        MARUÍPE            0
# 102796 2016-06-03 00:00:00+00:00  80.0  SÃO CRISTÓVÃO            0
#
#         hipertension  diabetes  ...            scheduled_date  \
# 3764               0         0  ... 2015-11-10 00:00:00+00:00
# 46292              1         0  ... 2015-12-03 00:00:00+00:00
# 102795             0         0  ... 2015-12-07 00:00:00+00:00
# 102797             1         1  ... 2015-12-07 00:00:00+00:00
# 102796             1         1  ... 2015-12-07 00:00:00+00:00
#
#                 appointment_date  waiting_days appointment_weekday  \
# 3764   2016-05-04 00:00:00+00:00           176           Wednesday
# 46292  2016-05-02 00:00:00+00:00           151              Monday
# 102795 2016-06-03 00:00:00+00:00           179              Friday
# 102797 2016-06-03 00:00:00+00:00           179              Friday
# 102796 2016-06-03 00:00:00+00:00           179              Friday
#
#        appointment_month has_disability  no_show_flag            age_group  \
# 3764                 May              0             0        Adult (36-55)
# 46292                May              0             1  Young Adult (18-35)
# 102795              June              0             1  Young Adult (18-35)
# 102797              June              0             0        Adult (36-55)
# 102796              June              0             0        Elderly (76+)
#
#        wait_time_group  high_risk_no_show
# 3764          30+ Days              False
# 46292         30+ Days              False
# 102795        30+ Days              False
# 102797        30+ Days              False
# 102796        30+ Days              False
#
# [5 rows x 24 columns]
